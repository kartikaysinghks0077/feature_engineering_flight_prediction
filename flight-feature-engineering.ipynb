# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/flight-data/Data_Train (1).xlsx
# /kaggle/input/flight-data/Test_set.xlsx

# %%
import pandas as pd

# %%
df=pd.read_excel('/kaggle/input/flight-data/Data_Train (1).xlsx')

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
df1=pd.read_excel('/kaggle/input/flight-data/Test_set.xlsx')

# %%
fdf1=pd.concat([df,df1],axis=0)

# %%
fdf1
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
fdf1['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
fdf1['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
fdf1['Date_of_Journey']=pd.to_datetime(fdf1['Date_of_Journey'])
# Out:
# /tmp/ipykernel_100/3486764899.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   fdf1['Date_of_Journey']=pd.to_datetime(fdf1['Date_of_Journey'])

# %%
fdf1['Date_of_Journey']
# Out:
# 0      2019-03-24
# 1      2019-05-01
# 2      2019-06-09
# 3      2019-05-12
# 4      2019-03-01
#           ...
# 2666   2019-06-06
# 2667   2019-03-27
# 2668   2019-03-06
# 2669   2019-03-06
# 2670   2019-06-15
# Name: Date_of_Journey, Length: 13354, dtype: datetime64[ns]

# %%
fdf1['year']=fdf1['Date_of_Journey'].dt.year

# %%
fdf1
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      2019-03-24  Banglore   New Delhi
# 1             Air India      2019-05-01   Kolkata    Banglore
# 2           Jet Airways      2019-06-09     Delhi      Cochin
# 3                IndiGo      2019-05-12   Kolkata    Banglore
# 4                IndiGo      2019-03-01  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India      2019-06-06   Kolkata    Banglore
# 2667             IndiGo      2019-03-27   Kolkata    Banglore
# 2668        Jet Airways      2019-03-06     Delhi      Cochin
# 2669          Air India      2019-03-06     Delhi      Cochin
# 2670  Multiple carriers      2019-06-15     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
fdf1['month']=fdf1['Date_of_Journey'].dt.month

# %%
fdf1['day']=fdf1['Date_of_Journey'].dt.day

# %%
fdf1
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      2019-03-24  Banglore   New Delhi
# 1             Air India      2019-05-01   Kolkata    Banglore
# 2           Jet Airways      2019-06-09     Delhi      Cochin
# 3                IndiGo      2019-05-12   Kolkata    Banglore
# 4                IndiGo      2019-03-01  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India      2019-06-06   Kolkata    Banglore
# 2667             IndiGo      2019-03-27   Kolkata    Banglore
# 2668        Jet Airways      2019-03-06     Delhi      Cochin
# 2669          Air India      2019-03-06     Delhi      Cochin
# 2670  Multiple carriers      2019-06-15     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
fdf1['year'].astype(int),fdf1['month'].astype(int),fdf1['day'].astype(int)
# Out:
# (0       2019
#  1       2019
#  2       2019
#  3       2019
#  4       2019
#          ...
#  2666    2019
#  2667    2019
#  2668    2019
#  2669    2019
#  2670    2019
#  Name: year, Length: 13354, dtype: int64,
#  0       3
#  1       5
#  2       6
#  3       5
#  4       3
#         ..
#  2666    6
#  2667    3
#  2668    3
#  2669    3
#  2670    6
#  Name: month, Length: 13354, dtype: int64,
#  0       24
#  1        1
#  2        9
#  3       12
#  4        1
#          ..
#  2666     6
#  2667    27
#  2668     6
#  2669     6
#  2670    15
#  Name: day, Length: 13354, dtype: int64)

# %%
fdf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  datetime64[ns]
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  year             13354 non-null  int32
#  12  month            13354 non-null  int32
#  13  day              13354 non-null  int32
# dtypes: datetime64[ns](1), float64(1), int32(3), object(9)
# memory usage: 1.4+ MB

# %%
fdf1.drop(columns=['Date_of_Journey'],inplace=True)

# %%
fdf1
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
# ...

# %%
fdf1[['Arrival_time','kachra']]=fdf1['Arrival_Time'].str.split(' ',expand=True, n=1)

# %%
fdf1
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
# ...

# %%
fdf1.drop(columns=['kachra'],inplace=True)

# %%
fdf1
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
# ...

# %%
fdf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Arrival_Time     13354 non-null  object
#  6   Duration         13354 non-null  object
#  7   Total_Stops      13353 non-null  object
#  8   Additional_Info  13354 non-null  object
#  9   Price            10683 non-null  float64
#  10  year             13354 non-null  int32
#  11  month            13354 non-null  int32
#  12  day              13354 non-null  int32
#  13  Arrival_time     13354 non-null  object
# dtypes: float64(1), int32(3), object(10)
# memory usage: 1.4+ MB

# %%
fdf1['Arrival_time']=pd.to_datetime(fdf1['Arrival_time'])
# Out:
# /tmp/ipykernel_100/2827670217.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   fdf1['Arrival_time']=pd.to_datetime(fdf1['Arrival_time'])

# %%
fdf1.drop(columns=['Arrival_time'],inplace=True)

# %%
fdf1
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
# ...

# %%
fdf1[['Arrival_time','kachra']]=fdf1['Arrival_Time'].str.split(' ',expand=True, n=1)

# %%
fdf1.drop(columns=['kachra'],inplace=True)

# %%
fdf1
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
# ...

# %%
fdf1[['Arrival_hour','Arrival_min']]=fdf1['Arrival_time'].str.split(':',expand=True, n=1)

# %%
fdf1
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
# ...

# %%
fdf1[['Arrival_hour','Arrival_min']]=fdf1[['Arrival_hour','Arrival_min']].astype(int)

# %%
fdf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Arrival_Time     13354 non-null  object
#  6   Duration         13354 non-null  object
#  7   Total_Stops      13353 non-null  object
#  8   Additional_Info  13354 non-null  object
#  9   Price            10683 non-null  float64
#  10  year             13354 non-null  int32
#  11  month            13354 non-null  int32
#  12  day              13354 non-null  int32
#  13  Arrival_time     13354 non-null  object
#  14  Arrival_hour     13354 non-null  int64
#  15  Arrival_min      13354 non-null  int64
# ...

# %%
fdf1.drop('Arrival_time',axis=1,inplace=True)

# %%
fdf1
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
# ...

# %%
fdf1.drop('Arrival_Time',axis=1,inplace=True)

# %%
fdf1[['Departure_hour','Departure_min']]=fdf1['Dep_Time'].str.split(':',expand=True, n=1)

# %%
fdf1
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
# ...

# %%
fdf1[['Departure_hour','Departure_min']]=fdf1[['Departure_hour','Departure_min']].astype(int)

# %%
fdf1
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...                 ...       ...         ...                    ...      ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
# ...

# %%
fdf1.drop('Dep_Time',axis=1,inplace=True)

# %%
fdf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Duration         13354 non-null  object
#  5   Total_Stops      13353 non-null  object
#  6   Additional_Info  13354 non-null  object
#  7   Price            10683 non-null  float64
#  8   year             13354 non-null  int32
#  9   month            13354 non-null  int32
#  10  day              13354 non-null  int32
#  11  Arrival_hour     13354 non-null  int64
#  12  Arrival_min      13354 non-null  int64
#  13  Departure_hour   13354 non-null  int64
#  14  Departure_min    13354 non-null  int64
# dtypes: float64(1), int32(3), int64(4), object(7)
# memory usage: 1.5+ MB

# %%
fdf1['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
fdf1[fdf1['Total_Stops'].isna()]
# Out:
#         Airline Source Destination Route Duration Total_Stops Additional_Info  \
# 9039  Air India  Delhi      Cochin   NaN  23h 40m         NaN         No info
#
#        Price  year  month  day  Arrival_hour  Arrival_min  Departure_hour  \
# 9039  7480.0  2019      5    6             9           25               9
#
#       Departure_min
# 9039             45

# %%
fdf1['Total_Stops']=fdf1['Total_Stops'].map({'non-stop':0,'2 stops':2,'1 stop':1,'4 stops':4, 'nan':2})

# %%
fdf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Duration         13354 non-null  object
#  5   Total_Stops      13297 non-null  float64
#  6   Additional_Info  13354 non-null  object
#  7   Price            10683 non-null  float64
#  8   year             13354 non-null  int32
#  9   month            13354 non-null  int32
#  10  day              13354 non-null  int32
#  11  Arrival_hour     13354 non-null  int64
#  12  Arrival_min      13354 non-null  int64
#  13  Departure_hour   13354 non-null  int64
#  14  Departure_min    13354 non-null  int64
# dtypes: float64(2), int32(3), int64(4), object(6)
# memory usage: 1.5+ MB

# %%
fdf1.drop('Route',axis=1,inplace=True)

# %%
fdf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Duration         13354 non-null  object
#  4   Total_Stops      13297 non-null  float64
#  5   Additional_Info  13354 non-null  object
#  6   Price            10683 non-null  float64
#  7   year             13354 non-null  int32
#  8   month            13354 non-null  int32
#  9   day              13354 non-null  int32
#  10  Arrival_hour     13354 non-null  int64
#  11  Arrival_min      13354 non-null  int64
#  12  Departure_hour   13354 non-null  int64
#  13  Departure_min    13354 non-null  int64
# dtypes: float64(2), int32(3), int64(4), object(5)
# memory usage: 1.4+ MB

# %%
fdf1[['Duration_hr','duration-min']]=df['Duration'].str.split(' ',expand=True,n=1)

# %%
fdf1
# Out:
#                 Airline    Source Destination Duration  Total_Stops  \
# 0                IndiGo  Banglore   New Delhi   2h 50m          0.0
# 1             Air India   Kolkata    Banglore   7h 25m          2.0
# 2           Jet Airways     Delhi      Cochin      19h          2.0
# 3                IndiGo   Kolkata    Banglore   5h 25m          1.0
# 4                IndiGo  Banglore   New Delhi   4h 45m          1.0
# ...                 ...       ...         ...      ...          ...
# 2666          Air India   Kolkata    Banglore  23h 55m          1.0
# 2667             IndiGo   Kolkata    Banglore   2h 35m          0.0
# 2668        Jet Airways     Delhi      Cochin   6h 35m          1.0
# 2669          Air India     Delhi      Cochin  15h 15m          1.0
# 2670  Multiple carriers     Delhi      Cochin  14h 20m          1.0
#
#      Additional_Info    Price  year  month  day  Arrival_hour  Arrival_min  \
# ...

# %%
fdf1['Duration_hr'] = fdf1['Duration_hr'].str.replace('h', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 fdf1['Duration_hr'] = fdf1['Duration_hr'].str.replace('h', '').astype(int)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
# ...

# %%
fdf1[fdf1['Duration_hr'].str.contains('m')]
# Out:
#         Airline  Source Destination Duration  Total_Stops Additional_Info  \
# 6474  Air India  Mumbai   Hyderabad       5m          2.0         No info
#
#         Price  year  month  day  Arrival_hour  Arrival_min  Departure_hour  \
# 6474  17327.0  2019      3    6            16           55              16
#
#       Departure_min Duration_hr duration-min
# 6474             50          5m         None

# %%
fdf1['duration-min'].loc[fdf1['Duration_hr'].str.contains('m')]='5m' # fdf1.loc[fdf1['Duration_hr'].str.contains('m'), 'duration-min'] = '5m' use this in future
# Out:
# /tmp/ipykernel_100/2944234344.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   fdf1['duration-min'].loc[fdf1['Duration_hr'].str.contains('m')]='5m'
# /tmp/ipykernel_100/2944234344.py:1: SettingWithCopyWarning:
# ...

# %%
fdf1['Duration_hr'].loc[fdf1['Duration_hr'].str.contains('m')]='0h'
# Out:
# /tmp/ipykernel_100/2115621652.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fdf1['Duration_hr'].loc[fdf1['Duration_hr'].str.contains('m')]='0h'

# %%
fdf1
# Out:
#                 Airline    Source Destination Duration  Total_Stops  \
# 0                IndiGo  Banglore   New Delhi   2h 50m          0.0
# 1             Air India   Kolkata    Banglore   7h 25m          2.0
# 2           Jet Airways     Delhi      Cochin      19h          2.0
# 3                IndiGo   Kolkata    Banglore   5h 25m          1.0
# 4                IndiGo  Banglore   New Delhi   4h 45m          1.0
# ...                 ...       ...         ...      ...          ...
# 2666          Air India   Kolkata    Banglore  23h 55m          1.0
# 2667             IndiGo   Kolkata    Banglore   2h 35m          0.0
# 2668        Jet Airways     Delhi      Cochin   6h 35m          1.0
# 2669          Air India     Delhi      Cochin  15h 15m          1.0
# 2670  Multiple carriers     Delhi      Cochin  14h 20m          1.0
#
#      Additional_Info    Price  year  month  day  Arrival_hour  Arrival_min  \
# ...

# %%
fdf1[fdf1['Duration_hr']=='0h']
# Out:
#         Airline  Source Destination Duration  Total_Stops Additional_Info  \
# 6474  Air India  Mumbai   Hyderabad       5m          2.0         No info
#
#         Price  year  month  day  Arrival_hour  Arrival_min  Departure_hour  \
# 6474  17327.0  2019      3    6            16           55              16
#
#       Departure_min Duration_hr duration-min
# 6474             50          0h           5m

# %%
fdf1['Duration_hr'].unique()
# Out:
# array(['2h', '7h', '19h', '5h', '4h', '15h', '21h', '25h', '13h', '12h',
#        '26h', '22h', '23h', '20h', '10h', '6h', '11h', '8h', '16h', '3h',
#        '27h', '1h', '14h', '9h', '18h', '17h', '24h', '30h', '28h', '29h',
#        '37h', '34h', '38h', '35h', '36h', '47h', '33h', '32h', '31h',
#        '42h', '39h', '0h', '41h', '40h'], dtype=object)

# %%
fdf1['Duration_hr'] = fdf1['Duration_hr'].str.replace('h', '').astype(int)

# %%
fdf1['Duration_hr'].dtype
# Out:
# dtype('int64')

# %%
fdf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Duration         13354 non-null  object
#  4   Total_Stops      13297 non-null  float64
#  5   Additional_Info  13354 non-null  object
#  6   Price            10683 non-null  float64
#  7   year             13354 non-null  int32
#  8   month            13354 non-null  int32
#  9   day              13354 non-null  int32
#  10  Arrival_hour     13354 non-null  int64
#  11  Arrival_min      13354 non-null  int64
#  12  Departure_hour   13354 non-null  int64
#  13  Departure_min    13354 non-null  int64
#  14  Duration_hr      13354 non-null  int64
#  15  duration-min     12071 non-null  object
# dtypes: float64(2), int32(3), int64(5), object(6)
# ...

# %%
a=np.array(fdf1['Duration_hr'])

# %%
a=a*60

# %%
a
# Out:
# array([ 120,  420, 1140, ..., 1200,  120,  300])

# %%
fdf1['Duration_hr1']=pd.DataFrame(a)

# %%
fdf1
# Out:
#                 Airline    Source Destination Duration  Total_Stops  \
# 0                IndiGo  Banglore   New Delhi   2h 50m          0.0
# 1             Air India   Kolkata    Banglore   7h 25m          2.0
# 2           Jet Airways     Delhi      Cochin      19h          2.0
# 3                IndiGo   Kolkata    Banglore   5h 25m          1.0
# 4                IndiGo  Banglore   New Delhi   4h 45m          1.0
# ...                 ...       ...         ...      ...          ...
# 2666          Air India   Kolkata    Banglore  23h 55m          1.0
# 2667             IndiGo   Kolkata    Banglore   2h 35m          0.0
# 2668        Jet Airways     Delhi      Cochin   6h 35m          1.0
# 2669          Air India     Delhi      Cochin  15h 15m          1.0
# 2670  Multiple carriers     Delhi      Cochin  14h 20m          1.0
#
#      Additional_Info    Price  year  month  day  Arrival_hour  Arrival_min  \
# ...

# %%
fdf1['duration-min'].unique()
# Out:
# array(['50m', '25m', None, '45m', '30m', '5m', '15m', '35m', '10m', '20m',
#        '55m', '40m'], dtype=object)

# %%
fdf1['duration-min']=fdf1['duration-min'].str.replace('None','0m')

# %%
fdf1[fdf1['duration-min'].isna()]
# Out:
#                 Airline    Source Destination Duration  Total_Stops  \
# 2           Jet Airways     Delhi      Cochin      19h          2.0
# 18            Air India     Delhi      Cochin      23h          2.0
# 33          Jet Airways     Delhi      Cochin      22h          2.0
# 44    Multiple carriers     Delhi      Cochin      12h          1.0
# 53               IndiGo  Banglore       Delhi       3h          0.0
# ...                 ...       ...         ...      ...          ...
# 2610           SpiceJet   Chennai     Kolkata   2h 20m          0.0
# 2627          Air India     Delhi      Cochin  22h 30m          1.0
# 2644  Multiple carriers     Delhi      Cochin  11h 30m          1.0
# 2659        Jet Airways     Delhi      Cochin    7h 5m          2.0
# 2660          Air India    Mumbai   Hyderabad       5m          2.0
#
#                    Additional_Info    Price  year  month  day  Arrival_hour  \
# ...

# %%
fdf1[fdf1['duration-min'].isna()].fillna('0m')
# Out:
#                 Airline    Source Destination Duration Total_Stops  \
# 2           Jet Airways     Delhi      Cochin      19h         2.0
# 18            Air India     Delhi      Cochin      23h         2.0
# 33          Jet Airways     Delhi      Cochin      22h         2.0
# 44    Multiple carriers     Delhi      Cochin      12h         1.0
# 53               IndiGo  Banglore       Delhi       3h         0.0
# ...                 ...       ...         ...      ...         ...
# 2610           SpiceJet   Chennai     Kolkata   2h 20m         0.0
# 2627          Air India     Delhi      Cochin  22h 30m         1.0
# 2644  Multiple carriers     Delhi      Cochin  11h 30m         1.0
# 2659        Jet Airways     Delhi      Cochin    7h 5m         2.0
# 2660          Air India    Mumbai   Hyderabad       5m         2.0
#
#                    Additional_Info    Price  year  month  day  Arrival_hour  \
# 2                          No info  13882.0  2019      6    9             4
# ...

# %%
fdf1['duration-min'] = fdf1['duration-min'].fillna('0m')

# %%
fdf1['duration-min']=fdf1['duration-min'].str
# Out:
# 0       50m
# 1       25m
# 2        0m
# 3       25m
# 4       45m
#        ...
# 2666    25m
# 2667    35m
# 2668    10m
# 2669    50m
# 2670    35m
# Name: duration-min, Length: 13354, dtype: object

# %%
fdf1['duration-min'] = fdf1['duration-min'].str.replace('m', '').astype(int)

# %%
fdf1['duration-min']
# Out:
# 0       50
# 1       25
# 2        0
# 3       25
# 4       45
#         ..
# 2666    25
# 2667    35
# 2668    10
# 2669    50
# 2670    35
# Name: duration-min, Length: 13354, dtype: int64

# %%
a=np.array([1,2,3])
b=np.array([1,2,3])
a+b
# Out:
# array([2, 4, 6])

# %%
fdf1
# Out:
#                 Airline    Source Destination Duration  Total_Stops  \
# 0                IndiGo  Banglore   New Delhi   2h 50m          0.0
# 1             Air India   Kolkata    Banglore   7h 25m          2.0
# 2           Jet Airways     Delhi      Cochin      19h          2.0
# 3                IndiGo   Kolkata    Banglore   5h 25m          1.0
# 4                IndiGo  Banglore   New Delhi   4h 45m          1.0
# ...                 ...       ...         ...      ...          ...
# 2666          Air India   Kolkata    Banglore  23h 55m          1.0
# 2667             IndiGo   Kolkata    Banglore   2h 35m          0.0
# 2668        Jet Airways     Delhi      Cochin   6h 35m          1.0
# 2669          Air India     Delhi      Cochin  15h 15m          1.0
# 2670  Multiple carriers     Delhi      Cochin  14h 20m          1.0
#
#      Additional_Info    Price  year  month  day  Arrival_hour  Arrival_min  \
# ...

# %%
a=np.array(fdf1['duration-min'])
b=np.array(fdf1['Duration_hr1'])

# %%
c=a+b

# %%
c
# Out:
# array([ 170,  445, 1140, ..., 1210,  170,  335])

# %%
fdf1['Total_duration']=pd.DataFrame(c)

# %%
fdf1
# Out:
#                 Airline    Source Destination Duration  Total_Stops  \
# 0                IndiGo  Banglore   New Delhi   2h 50m          0.0
# 1             Air India   Kolkata    Banglore   7h 25m          2.0
# 2           Jet Airways     Delhi      Cochin      19h          2.0
# 3                IndiGo   Kolkata    Banglore   5h 25m          1.0
# 4                IndiGo  Banglore   New Delhi   4h 45m          1.0
# ...                 ...       ...         ...      ...          ...
# 2666          Air India   Kolkata    Banglore  23h 55m          1.0
# 2667             IndiGo   Kolkata    Banglore   2h 35m          0.0
# 2668        Jet Airways     Delhi      Cochin   6h 35m          1.0
# 2669          Air India     Delhi      Cochin  15h 15m          1.0
# 2670  Multiple carriers     Delhi      Cochin  14h 20m          1.0
#
#      Additional_Info    Price  year  month  day  Arrival_hour  Arrival_min  \
# ...

# %%
fdf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Duration         13354 non-null  object
#  4   Total_Stops      13297 non-null  float64
#  5   Additional_Info  13354 non-null  object
#  6   Price            10683 non-null  float64
#  7   year             13354 non-null  int32
#  8   month            13354 non-null  int32
#  9   day              13354 non-null  int32
#  10  Arrival_hour     13354 non-null  int64
#  11  Arrival_min      13354 non-null  int64
#  12  Departure_hour   13354 non-null  int64
#  13  Departure_min    13354 non-null  int64
#  14  Duration_hr      13354 non-null  int64
#  15  duration-min     13354 non-null  int64
#  16  Duration_hr1     13354 non-null  int64
# ...

# %%
fdf1.drop(columns=['Duration'],inplace=True)

# %%
fdf1
# Out:
#                 Airline    Source Destination  Total_Stops Additional_Info  \
# 0                IndiGo  Banglore   New Delhi          0.0         No info
# 1             Air India   Kolkata    Banglore          2.0         No info
# 2           Jet Airways     Delhi      Cochin          2.0         No info
# 3                IndiGo   Kolkata    Banglore          1.0         No info
# 4                IndiGo  Banglore   New Delhi          1.0         No info
# ...                 ...       ...         ...          ...             ...
# 2666          Air India   Kolkata    Banglore          1.0         No info
# 2667             IndiGo   Kolkata    Banglore          0.0         No info
# 2668        Jet Airways     Delhi      Cochin          1.0         No info
# 2669          Air India     Delhi      Cochin          1.0         No info
# 2670  Multiple carriers     Delhi      Cochin          1.0         No info
#
# ...

# %%
fdf1['Total_Stops'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 13354 entries, 0 to 2670
# Series name: Total_Stops
# Non-Null Count  Dtype
# --------------  -----
# 13297 non-null  float64
# dtypes: float64(1)
# memory usage: 208.7 KB

# %%
fdf1['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
fdf1['Airline']=le.fit_transform(fdf1['Airline'])

# %%
fdf1['Airline']
# Out:
# 0       3
# 1       1
# 2       4
# 3       3
# 4       3
#        ..
# 2666    1
# 2667    3
# 2668    4
# 2669    1
# 2670    6
# Name: Airline, Length: 13354, dtype: int64

# %%
fdf1['Additional_Info']=le.fit_transform(fdf1['Additional_Info'])

# %%
fdf1['Source']=le.fit_transform(fdf1['Source'])

# %%
fdf1['Destination']=le.fit_transform(fdf1['Destination'])

# %%
fdf1
# Out:
#       Airline  Source  Destination  Total_Stops  Additional_Info    Price  \
# 0           3       0            5          0.0                8   3897.0
# 1           1       3            0          2.0                8   7662.0
# 2           4       2            1          2.0                8  13882.0
# 3           3       3            0          1.0                8   6218.0
# 4           3       0            5          1.0                8  13302.0
# ...       ...     ...          ...          ...              ...      ...
# 2666        1       3            0          1.0                8      NaN
# 2667        3       3            0          0.0                8      NaN
# 2668        4       2            1          1.0                8      NaN
# 2669        1       2            1          1.0                8      NaN
# 2670        6       2            1          1.0                8      NaN
#
#       year  month  day  Arrival_hour  Arrival_min  Departure_hour  \
# ...

# %%
#we have to drop duration-hr1 and duration min

# %%
pd.get_dummies(fdf1,columns=['Airline','Source','Destination','Additional_Info'],drop_first=True,dtype=int)
# Out:
#       Total_Stops    Price  year  month  day  Arrival_hour  Arrival_min  \
# 0             0.0   3897.0  2019      3   24             1           10
# 1             2.0   7662.0  2019      5    1            13           15
# 2             2.0  13882.0  2019      6    9             4           25
# 3             1.0   6218.0  2019      5   12            23           30
# 4             1.0  13302.0  2019      3    1            21           35
# ...           ...      ...   ...    ...  ...           ...          ...
# 2666          1.0      NaN  2019      6    6            20           25
# 2667          0.0      NaN  2019      3   27            16           55
# 2668          1.0      NaN  2019      3    6             4           25
# 2669          1.0      NaN  2019      3    6            19           15
# 2670          1.0      NaN  2019      6   15            19           15
#
#       Departure_hour  Departure_min  Duration_hr  ...  Destination_5  \
# ...
